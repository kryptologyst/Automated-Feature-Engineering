# %% [markdown]
# # Automated Feature Engineering - Quick Start
#
# This notebook demonstrates the basic usage of the automated feature engineering system.
#
# ## ⚠️ Disclaimer
# This is a research/educational demo. NOT for production decisions or control systems.

# %%
# Import required libraries
import sys
from pathlib import Path

# Add src to path
sys.path.append(str(Path.cwd() / "src"))

from src.train import AutomatedFeatureEngineeringTrainer
from src.data import BostonHousingDataModule
from src.models import ClassicalBaseline, AutoMLModel
from src.data.feature_engineering import BasicFeaturePipeline, AdvancedFeaturePipeline
from src.metrics import ModelEvaluator
from src.viz import FeatureEngineeringVisualizer

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
